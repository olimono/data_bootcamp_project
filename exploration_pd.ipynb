# %% [markdown]
# **Librerías**

# %%
import pandas as pd

# %% [markdown]
# **Lectura de datos**

# %%
airbnb = pd.read_csv('airbnb-listings.csv', sep = ';', decimal = '.')

# %% [markdown]
# **Análisis Exploratorio**

# %%
#TAMAÑO DEL DATASET
airbnb.shape
# Out:
# (14780, 89)

# %%
#MUESTRA DE PRIMEROS REGISTROS DEL DATASET
airbnb.head(3)
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  15141125  https://www.airbnb.com/rooms/15141125  20170407214119
# 1   9470166   https://www.airbnb.com/rooms/9470166  20170407214119
# 2  17444981  https://www.airbnb.com/rooms/17444981  20170407214119
#
#   Last Scraped                                 Name  \
# 0   2017-04-08           Panoramic charming studio!
# 1   2017-04-08  Comfortable penthouse in the center
# 2   2017-04-08         Cosy Apartment SOL/LA LATINA
#
#                                              Summary  \
# 0  Charming bright and cosy studio in "El Rastro"...
# 1  In the center, recently remodeled, comfortable...
# 2  Nice apartment near Sol and La Latina. Perfect...
#
#                                                Space  \
# 0  It's a bright and cosy studio located in the h...
# 1  Quiet and comfortable space where you can rela...
# 2  Is a really cosy apartment with the best locat...
#
# ...

# %%
airbnb.describe()
# Out:
#                  ID     Scrape ID       Host ID  Host Response Rate  \
# count  1.478000e+04  1.478000e+04  1.478000e+04        12881.000000
# mean   1.028089e+07  2.017037e+13  3.608080e+07           94.823461
# std    5.564829e+06  5.667971e+08  3.425360e+07           15.215988
# min    1.862800e+04  2.016010e+13  1.745300e+04            0.000000
# 25%    5.554732e+06  2.017041e+13  6.787360e+06          100.000000
# 50%    1.133492e+07  2.017041e+13  2.464875e+07          100.000000
# 75%    1.532631e+07  2.017041e+13  5.432919e+07          100.000000
# max    1.910969e+07  2.017062e+13  1.247534e+08          100.000000
#
#        Host Listings Count  Host Total Listings Count      Latitude  \
# count         14777.000000               14777.000000  14780.000000
# mean             12.513636                  12.513636     40.497626
# std              34.090223                  34.090223      4.641387
# min               0.000000                   0.000000    -37.851182
# ...

# %%
#TODAS LAS COLUMNAS DEL DATASET
list(airbnb.columns)
# Out:
# ['ID',
#  'Listing Url',
#  'Scrape ID',
#  'Last Scraped',
#  'Name',
#  'Summary',
#  'Space',
#  'Description',
#  'Experiences Offered',
#  'Neighborhood Overview',
#  'Notes',
#  'Transit',
#  'Access',
#  'Interaction',
#  'House Rules',
#  'Thumbnail Url',
#  'Medium Url',
#  'Picture Url',
#  'XL Picture Url',
#  'Host ID',
#  'Host URL',
#  'Host Name',
#  'Host Since',
#  'Host Location',
#  'Host About',
#  'Host Response Time',
#  'Host Response Rate',
#  'Host Acceptance Rate',
#  'Host Thumbnail Url',
#  'Host Picture Url',
#  'Host Neighbourhood',
#  'Host Listings Count',
#  'Host Total Listings Count',
#  'Host Verifications',
#  'Street',
#  'Neighbourhood',
#  'Neighbourhood Cleansed',
#  'Neighbourhood Group Cleansed',
#  'City',
#  'State',
#  'Zipcode',
#  'Market',
#  'Smart Location',
#  'Country Code',
#  'Country',
#  'Latitude',
#  'Longitude',
#  'Property Type',
#  'Room Type',
#  'Accommodates',
#  'Bathrooms',
#  'Bedrooms',
#  'Beds',
#  'Bed Type',
# ...

# %% [markdown]
# **Limpiamos las variables que no utilizaremos**

# %%
#CAMPOS QUE NO APORTAN, LOS ELIMINAMOS
col_drop = ['Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary', 'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
 'Notes', 'Transit', 'Access', 'Interaction', 'House Rules', 'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url', 'Host ID', 'Host URL',
 'Host Name', 'Host Location', 'Host About', 'Host Response Time', 'Host Response Rate', 'Host Acceptance Rate', 'Host Thumbnail Url', 
 'Host Picture Url', 'Host Neighbourhood', 'Host Listings Count', 'Host Total Listings Count', 'Host Verifications',  'Street',  
 'Neighbourhood', 'Neighbourhood Cleansed', 'State', 'Market', 'Smart Location', 'Country Code', 'Country',
 'Weekly Price', 'Monthly Price',  'Guests Included', 'Extra People', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
 'Has Availability', 'Availability 30', 'Availability 60', 'Availability 90', 'Availability 365', 'Calendar last Scraped',  'First Review', 'Last Review',
 'Review Scores Accuracy', 'Review Scores Cleanliness', 'Review Scores Checkin', 'Review Scores Communication', 'Review Scores Location',
 'Review Scores Value',  'License', 'Jurisdiction Names', 'Calculated host listings count', 'Geolocation']

airbnb.drop(col_drop, axis=1, inplace=True)

# %%
# COLUMNAS QUE QUEDAN
list(airbnb.columns)
# Out:
# ['ID',
#  'Host Since',
#  'Neighbourhood Group Cleansed',
#  'City',
#  'Zipcode',
#  'Latitude',
#  'Longitude',
#  'Property Type',
#  'Room Type',
#  'Accommodates',
#  'Bathrooms',
#  'Bedrooms',
#  'Beds',
#  'Bed Type',
#  'Amenities',
#  'Square Feet',
#  'Price',
#  'Security Deposit',
#  'Cleaning Fee',
#  'Number of Reviews',
#  'Review Scores Rating',
#  'Cancellation Policy',
#  'Reviews per Month',
#  'Features']

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14780 entries, 0 to 14779
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            14780 non-null  int64
#  1   Host Since                    14777 non-null  object
#  2   Neighbourhood Group Cleansed  13760 non-null  object
#  3   City                          14774 non-null  object
#  4   Zipcode                       14274 non-null  object
#  5   Latitude                      14780 non-null  float64
#  6   Longitude                     14780 non-null  float64
#  7   Property Type                 14780 non-null  object
#  8   Room Type                     14780 non-null  object
#  9   Accommodates                  14780 non-null  int64
#  10  Bathrooms                     14725 non-null  float64
#  11  Bedrooms                      14755 non-null  float64
# ...

# %%
#ANÁLISIS DE MISSINGS
airbnb.isnull().sum().sort_values(ascending=False)
#airbnb.isna().sum().sort_values(ascending=False)
# Out:
# Square Feet                     14182
# Security Deposit                 8524
# Cleaning Fee                     6093
# Review Scores Rating             3304
# Reviews per Month                3162
# Neighbourhood Group Cleansed     1020
# Zipcode                           506
# Amenities                         170
# Bathrooms                          55
# Beds                               49
# Bedrooms                           25
# Price                              17
# City                                6
# Host Since                          3
# Features                            1
# Bed Type                            0
# Accommodates                        0
# Room Type                           0
# Property Type                       0
# Number of Reviews                   0
# Longitude                           0
# Cancellation Policy                 0
# Latitude                            0
# ID                                  0
# dtype: int64

# %%
#GUARDAMOS EL DATAFRAME MODIFICADO EN UN CSV

airbnb.to_csv("airbnb_clean.csv", index= False, sep=';')
